# %% [markdown]
# # ANSWER 1
# GET: To request data from the server.
#
# POST: To submit data to be processed to the server.

# %% [markdown]
# # ANSWER 2
# In a Flask App, we have our own Webpage (Client) and a Server. The Server should process the data. The Request, in Flask, is an object that contains all the data sent from the Client to Server. This data can be recovered using the GET/POST Methods.

# %% [markdown]
# # ANSWER 3
# The redirect() function allows us to redirect a user to the URL of our choice.
#
# Flask redirect is defined as a function or utility in Flask which allows developers to redirect users to a specified URL and assign a specified status code. When this function is called, a response object is returned, and the redirection happens to the target location with the status code.

# %% [markdown]
# # ANSWER 4
# Templates are files that contain static data as well as placeholders for dynamic data. A template is rendered with specific data to produce a final document.
#
# render_template is a Flask function from the flask. templating package. render_template is used to generate output from a template file based on the Jinja2 engine that is found in the application's templates folder.
#
# render_template is typically imported directly from the flask package instead of from flask.

# %% [markdown]
# # ANSWER 5
# ![Screenshot (383).png](attachment:b48153e4-8ce8-4e63-9aec-08702a36121d.png)
# ![Screenshot (382).png](attachment:beffcf0d-990c-4d23-8221-fa89d6e3bc3b.png)
# ![Screenshot (378).png](attachment:0d545ff6-8429-4c22-b9e4-32eab9979a28.png)
